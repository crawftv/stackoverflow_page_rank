# %% [markdown]
# # solved code

# %%
import pandas as pd
import numpy as np
import requests
import bs4

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
res = requests.get("https://stackoverflow.com/questions/541390")
res.status_code == requests.codes.ok
# Out:
# True

# %%
soup = bs4.BeautifulSoup(res.text)
# Out:
# C:\Users\cwcol\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\cwcol\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="html__responsive" itemscope="" itemtype="http://schema.org/QAPage">
# <head>
# <title>Extracting extension from filename in Python - Stack Overflow</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/img/favicon.ico?v=4f32ecc8f43d" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type"/>
# <meta content="https://stackoverflow.com/questions/541390/extracting-extension-from-filename-in-python" property="og:url"/>
# <meta content="Stack Overflow" property="og:site_name"/>
# ...

# %%
# get all links from answers from a post
posts =  soup.find_all('div' , {'class':'post-text'})
links = []
for n in posts:
    a = n.find_all('a')
    links.append(a)
flattened_list = [y for x in links for y in x]

# %%
flattened_list
# Out:
# [<a href="https://docs.python.org/2/library/os.path.html#os.path.splitext" rel="noreferrer">Python 2.X documentation</a>,
#  <a href="https://docs.python.org/3/library/os.path.html#os.path.splitext" rel="noreferrer">Python 3.X documentation</a>,
#  <a href="https://docs.python.org/3/library/pathlib.html" rel="noreferrer"><code>pathlib</code></a>,
#  <a href="https://stackoverflow.com/questions/6525334/getting-file-extension-using-pattern-matching-in-python">here</a>]

# %% [markdown]
# # Test, WIP

# %%
i = 541390
df[i] = [flattened_list]

# %%
res = requests.get("https://stackoverflow.com/questions/100000000")
res
# Out:
# <Response [404]>

# %%
type(post_soup)
# Out:
# bs4.element.Tag

# %%
post_links = []
for a in post_soup.find_all('a', href=True):
    post_links.append(a)

# %%
post_links
# Out:
# []

# %%
answer_links = [] 
answer_soup = soup.find_all('div', {'class': 'answercell post-layout--right'})

# %%
answer_soup
# Out:
# [<div class="answercell post-layout--right">
#  <div class="post-text" itemprop="text">
#  <p>Check out <a href="http://wummel.github.io/linkchecker/" rel="noreferrer">linkchecker</a>—it will crawl the site (while obeying <code>robots.txt</code>) and generate a report. From there, you can script up a solution for creating the directory tree.</p>
#  </div>
#  <div class="grid mb0 fw-wrap ai-start jc-end gs8 gsy">
#  <time datetime="2009-09-17T14:51:42" itemprop="dateCreated"></time>
#  <div class="grid--cell mr16" style="flex: 1 1 100px;">
#  <div class="post-menu"><a class="short-link" href="/a/1439372" id="link-post-1439372" itemprop="url" title="short permalink to this answer">share</a><span class="lsep">|</span><a class="suggest-edit-post" href="/posts/1439372/edit" title="">improve this answer</a></div> </div>
#  <div class="post-signature grid--cell fl0">
#  <div class="user-info ">
#  <div class="user-action-time">
# ...

# %%
for i in answer_soup:
    print(i,"END","\n")
# Out:
# <div class="answercell post-layout--right">
# <div class="post-text" itemprop="text">
# <p>Check out <a href="http://wummel.github.io/linkchecker/" rel="noreferrer">linkchecker</a>—it will crawl the site (while obeying <code>robots.txt</code>) and generate a report. From there, you can script up a solution for creating the directory tree.</p>
# </div>
# <div class="grid mb0 fw-wrap ai-start jc-end gs8 gsy">
# <time datetime="2009-09-17T14:51:42" itemprop="dateCreated"></time>
# <div class="grid--cell mr16" style="flex: 1 1 100px;">
# <div class="post-menu"><a class="short-link" href="/a/1439372" id="link-post-1439372" itemprop="url" title="short permalink to this answer">share</a><span class="lsep">|</span><a class="suggest-edit-post" href="/posts/1439372/edit" title="">improve this answer</a></div> </div>
# <div class="post-signature grid--cell fl0">
# <div class="user-info ">
# <div class="user-action-time">
# ...

# %%
p = soup.find_all('p')

# %%
type(p)
# Out:
# bs4.element.ResultSet

# %%
comment_soup = soup.find_all('div', {'class':'comment-body'})

# %%
comment_soup[0]
# Out:
# <div class="comment-body" style="display: block;">
# <span class="comment-copy">crawlmysite.in  - site not exists</span>
#
#                     – <a class="comment-user" href="/users/2320007/sarah-trees" title="195 reputation">Sarah Trees</a>
# <span class="comment-date" dir="ltr"><span class="relativetime-clean" title="2015-10-20 07:40:33Z">Oct 20 '15 at 7:40</span></span>
# </div>

# %%
comment_soup[0].a
# Out:
# <a class="comment-user" href="/users/2320007/sarah-trees" title="195 reputation">Sarah Trees</a>

# %%
comment_soup[1].a
# Out:
# <a class="comment-user owner" href="/users/100238/jonathan-lyon" title="1,596 reputation">Jonathan Lyon</a>

# %%
for i in comment_soup:
    print(i.a)
# Out:
# <a class="comment-user" href="/users/2320007/sarah-trees" title="195 reputation">Sarah Trees</a>
# <a class="comment-user owner" href="/users/100238/jonathan-lyon" title="1,596 reputation">Jonathan Lyon</a>
# <a class="comment-user" href="/users/283854/mateng" title="2,796 reputation">Mateng</a>
# <a class="comment-user" href="/users/1708058/alan-coromano" title="8,439 reputation">Alan Coromano</a>
# <a class="comment-user" href="/users/4203/hank-gay" title="51,790 reputation">Hank Gay</a>
# <a class="comment-user" href="/users/1366130/apexfred" title="194 reputation">ApexFred</a>
# <a class="comment-user" href="/users/632951/pacerier" title="43,741 reputation">Pacerier</a>
# <a class="comment-user" href="/users/3834297/electrobit" title="704 reputation">ElectroBit</a>
# <a class="comment-user" href="/users/632951/pacerier" title="43,741 reputation">Pacerier</a>
# <a href="http://stackoverflow.com/questions/1463867/javascript-double-dollar-sign">an arbitrary function name,</a>
# ...
